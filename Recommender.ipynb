# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# Out:
# C:\Anaconda\envs\gpu_3.7\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Anaconda\envs\gpu_3.7\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
# C:\Anaconda\envs\gpu_3.7\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)
# In C:\Anaconda\envs\gpu_3.7\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Anaconda\envs\gpu_3.7\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Anaconda\envs\gpu_3.7\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Anaconda\envs\gpu_3.7\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Anaconda\envs\gpu_3.7\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Anaconda\envs\gpu_3.7\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Anaconda\envs\gpu_3.7\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Anaconda\envs\gpu_3.7\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
dataset = pd.read_csv('C:\\Users\CoolT\Documents\Jupyternotebook3\WhiteAwayCase\Data\data.csv')

# %%
dataset
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
dataset['InvoiceNo'].min()
dataset['InvoiceNo'].max()
# Out:
# 'C581569'

# %%
unique_invoices = pd.unique(dataset['InvoiceNo'])
unique_stockcodes = pd.unique(dataset['StockCode'])

# %%
print(len(unique_invoices))
print(len(unique_stockcodes))
print(len(dataset))
a = []
# Out:
# 25900
# 4070
# 541909

# %%
#'71053' indices
index = dataset.index
indices_stock = index[dataset['StockCode'] == '71053']

stock_list = indices_stock.tolist()         #Giver en liste med index hvor specifikt item indgår

# %%
invoice_numbers = dataset['InvoiceNo'][stock_list]        
print(invoice_numbers)
#Giver liste med de tilhørende invoice numre til de index hvor specifikt item indgår
# Out:
# 1         536365
# 50        536373
# 67        536375
# 279       536396
# 417       536406
#            ...
# 534544    581149
# 534545    581149
# 536736    581219
# 539298    581439
# 541511    581498
# Name: InvoiceNo, Length: 355, dtype: object

# %%
index2 = dataset.index

indices_recommend_items = index[dataset['InvoiceNo'].isin(invoice_numbers)]

recommend_count_indices = indices_recommend_items.tolist()  
#Giver liste med index til de invoices hvor specifikt item indgår, flere index til samme invoice pga de fylder flere linjer

# %%
print(np.shape(recommend_count_indices))
# Out:
# (31988,)

# %%
recommend_count_list = dataset['StockCode'][recommend_count_indices] 
#laver en liste med alle de stockscodes fra de tilhørende invoices

# %%
print(recommend_count_list)
# Out:
# 0         85123A
# 1          71053
# 2         84406B
# 3         84029G
# 4         84029E
#            ...
# 541536    85099B
# 541537    85099C
# 541538     85150
# 541539     85174
# 541540       DOT
# Name: StockCode, Length: 31988, dtype: object

# %%
#unique_invoices = pd.unique(dataset['InvoiceNo'])
unique_stockcode_in_invoice = pd.unique(recommend_count_list)
#Laver en liste med unikke ting der er købt sammen med det første specificerede item

# %%
from collections import Counter
occurrences = Counter(recommend_count_list)
#Tæller sammen i en dictionary hvor mange der er af hver unik indgang

# %%
print(occurrences)
#Den første er det specifikke item selv, så den skal der ses bortfra. De andre er de recommende items.
# Out:
# Counter({'71053': 355, '85123A': 115, '22423': 93, '85099B': 92, 'DOT': 85, '22697': 84, '22699': 82, '22411': 81, '22960': 80, '22178': 76, '22666': 73, '22197': 72, '22457': 71, '47566': 71, '21931': 69, '85099C': 66, '21935': 65, '22993': 65, '22379': 64, '22961': 64, '21232': 64, '82482': 63, '22469': 63, '22386': 63, '22698': 62, '22720': 61, '21929': 60, '22784': 60, '21731': 59, '82580': 57, '23199': 57, '22630': 56, '21928': 55, '22470': 55, '20725': 54, '20712': 54, '84946': 53, '21790': 52, '21080': 52, '22424': 52, '22383': 51, '21212': 51, '22077': 50, '21174': 50, '21977': 49, '22464': 49, '22139': 49, '20724': 48, '20713': 48, '23301': 48, '23245': 48, '22659': 47, '20727': 47, '84029G': 46, '22219': 46, '22629': 46, '84380': 46, '84991': 46, '22722': 46, '23201': 46, '23300': 45, '84970S': 44, '23